# %%
name = "Rohmat"
greeting = "Selamat pagi"
print(f"Hai {name}, ucapkan {greeting}")
salam = name + ", " + greeting
print(salam)
# Out:
# Hai Rohmat, ucapkan Selamat pagi
# Rohmat, Selamat pagi

# %%
# Dari freeCodeCamp membangun caesar cypher text


# deklarasikan variabel caesar dengan 3 parameter
def caesar(text, shift, encrypt=True):
    # parameter shift harus berisi argumen berjenis int
    if not isinstance(shift, int):
        return "Shift must be an integer value."
    # parameter shift harus berisi argumen berjenis int diantara 1 dan 25
    if shift < 1 or shift > 25:
        return "Shift must be an integer between 1 and 25."
    # deklarasikan variabel alphabet dan inisiasikan dengan huruf a s.d. z
    alphabet = "abcdefghijklmnopqrstuvwxyz"
    # buat seleksi untuk decrypt maka angka integer akan bertanda kebalikan
    if not encrypt:
        shift = -shift

    shifted_alphabet = alphabet[shift:] + alphabet[:shift]
    translation_table = str.maketrans(
        alphabet + alphabet.upper(), shifted_alphabet + shifted_alphabet.upper()
    )
    encrypted_text = text.translate(translation_table)
    print(shifted_alphabet)
    print(translation_table)
    return encrypted_text


def encrypt(text, shift):
    return caesar(text, shift)


def decrypt(text, shift):
    return caesar(text, shift, encrypt=False)


encrypted_text = encrypt("freeCodeCamp", 3)
print(encrypted_text)

encrypted_text = "Pbhentr vf sbhaq va hayvxryl cynprf"
decrypted_text = decrypt(encrypted_text, 13)
print(decrypted_text)
# Out:
# defghijklmnopqrstuvwxyzabc
# {97: 100, 98: 101, 99: 102, 100: 103, 101: 104, 102: 105, 103: 106, 104: 107, 105: 108, 106: 109, 107: 110, 108: 111, 109: 112, 110: 113, 111: 114, 112: 115, 113: 116, 114: 117, 115: 118, 116: 119, 117: 120, 118: 121, 119: 122, 120: 97, 121: 98, 122: 99, 65: 68, 66: 69, 67: 70, 68: 71, 69: 72, 70: 73, 71: 74, 72: 75, 73: 76, 74: 77, 75: 78, 76: 79, 77: 80, 78: 81, 79: 82, 80: 83, 81: 84, 82: 85, 83: 86, 84: 87, 85: 88, 86: 89, 87: 90, 88: 65, 89: 66, 90: 67}
# iuhhFrghFdps
# nopqrstuvwxyzabcdefghijklm
# ...

# %%
text = "Rohmat Sunaryo"

print(f"Adalah {text[3:]}")
print(f"Adalah {text[:-3]}")
print(f"Adalah {text[::3]}")
print(f"Adalah {text[::-2]}")
print(f"Adalah {text[4::-3]}")
print(f"Adalah {text[:3:-2]}")
# Out:
# Adalah mat Sunaryo
# Adalah Rohmat Suna
# Adalah Rm ny
# Adalah ornStmo
# Adalah ao
# Adalah ornSt
