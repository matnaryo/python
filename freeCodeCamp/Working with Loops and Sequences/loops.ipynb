# %% [markdown]
# ### How Do Loops Work?

# %% [markdown]
# Loops are used to repeat a block of code. In this lesson, you will learn how to work with different types of loops in Python.
#
# The first loop we will go over is the `for` loop. Here is an example of using a `for` loop to iterate through a list and print each item to the console:

# %%
bahasa = ["Rust", "Java", "Python", "C++"]
for x in bahasa:
    print(x)
# Out:
# Rust
# Java
# Python

# %% [markdown]
# You can also use a `for` loop to iterate through other iterables like a string. Here is an example of using a `for` loop to loop through the string `code` and print out each character:

# %%
for char in "code":
    print(char)
# Out:
# c
# o
# d
# e

# %% [markdown]
# You can nest `for` loops in Python. Here is an example of a nested `for` loop:

# %%
kategori = ["Buah", "Sayur"]
makanan = ["Apel", "Wortel", "Pisang"]

for item in kategori:
    for makan in makanan:
        print(item, makan)
# Out:
# Buah Apel
# Buah Wortel
# Buah Pisang
# Sayur Apel
# Sayur Wortel
# Sayur Pisang

# %% [markdown]
# Another type of loop you can use in Python is the `while` loop. This type of loop will repeat a block of code until the condition is `False`. Here is an example of using a `while` loop for a guessing game:

# %%
angka_rahasia = 3
tebak = 0

while tebak != angka_rahasia:
    tebak = int(input("Tebak angka (1-5): "))
    if tebak != angka_rahasia:
        print("Salah! Coba lagi,")

print("Tebakan kamu benar")
# Out:
# Salah! Coba lagi,
# Salah! Coba lagi,
# Tebakan kamu benar

# %% [markdown]
# Python supports the `break` and `continue` statements.
#
# The `break` statement is used to stop the execution of a loop. Here is an example of using the `break` statement for a list of developer_names:

# %%
developer_names = ["Jess", "Rohmat", "Sunaryo"]

for developer in developer_names:
    if developer == "Sunaryo":
        break
    print(developer)
# Out:
# Jess
# Rohmat

# %% [markdown]
# The `continue` statement is used to skip the current iteration of a loop and move onto the next iteration. Let's modify the example from earlier to use the `continue` statement instead of `break`:

# %%
developer_names = ["Jess", "Rohmat", "Sunaryo"]

for developer in developer_names:
    if developer == "Jess":
        continue
    print(developer)
# Out:
# Rohmat
# Sunaryo

# %% [markdown]
# Both `for` and `while` loops can be combined with an `else` clause, which is executed only when the loop is not terminated by a `break` statement. Here is an example of using multiple `for` loops:

# %%
kata = ["sky", "apple", "rhythm", "fly", "orange"]

for item in kata:
    for huruf in item:
        if huruf.lower() in "aiueo":
            print(f"'{item}' terdiri dari vowel '{huruf}")
            break
    else:
        print(f"'{item}' tidak punya vowel")
# Out:
# 'sky' tidak punya vowel
# 'apple' terdiri dari vowel 'a
# 'rhythm' tidak punya vowel
# 'fly' tidak punya vowel
# 'orange' terdiri dari vowel 'o
