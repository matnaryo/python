# %%
guru = [
    "Rohmat",
    "Sunaryo",
    "Hilmi",
]

# %%
print(guru[0])
print(guru[-1])
# Out:
# Rohmat
# Hilmi

# %%
profil = ["Rohmat", 34, "Pawang Python"]
nama, umur, rule, kerja = profil
print(nama)
print(umur)
print(rule)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 profil = ["Rohmat", 34, "Pawang Python"]
# ----> 2 nama, umur, rule,kerja = profil
#       3 print(nama)
#       4 print(umur)
#       5 print(rule)
#
# ValueError: not enough values to unpack (expected 4, got 3)
